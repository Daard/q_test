# %%
import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"  
os.environ["CUDA_VISIBLE_DEVICES"]="2"

import warnings
warnings.filterwarnings('ignore')
from typing import Dict, List, Text
from collections import namedtuple

import tensorflow as tf
import tensorflow_data_validation as tfdv
import tensorflow_transform as tft
from tensorflow.keras.models import Sequential
import re

from tensorflow.keras.layers import (Dense, Dropout, Embedding, Lambda, Activation, BatchNormalization, Input) 

import numpy as np
import pandas as pd
from tqdm import tqdm
from train import build_callbacks

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
name = 'transform'
tr_dir = f'./tfx/pipelines/{name}/Transform'
tr_id = 4

shema_dir = os.path.join(tr_dir, f'post_transform_schema/{tr_id}/schema.pbtxt')
schema = tfdv.load_schema_text(shema_dir)
tfdv.display_schema(schema)
# Out:
#                    Type  Presence Valency Domain
# Feature name
# 'big_columns'     FLOAT  required              -
# 'categorical'       INT  required              -
# 'medium_columns'  FLOAT  required              -
# 'small_columns'   FLOAT  required              -
# 'target'          FLOAT  required              -
# 'z_normal'        FLOAT  required              -

# %%
output_dir = os.path.join(tr_dir, f'transform_graph/{tr_id}/')
tf_transform_output = tft.TFTransformOutput(output_dir)
feature_spec = tf_transform_output.transformed_feature_spec()
feature_spec
# Out:
# {'big_columns': FixedLenFeature(shape=[10], dtype=tf.float32, default_value=None),
#  'categorical': FixedLenFeature(shape=[1], dtype=tf.int64, default_value=None),
#  'medium_columns': FixedLenFeature(shape=[40], dtype=tf.float32, default_value=None),
#  'small_columns': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None),
#  'target': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None),
#  'z_normal': FixedLenFeature(shape=[1], dtype=tf.float32, default_value=None)}

# %%
train_file_pattern = os.path.join(tr_dir, f'transformed_examples/{tr_id}/Split-train/transformed_examples-00000-of-00001.gz')
val_file_pattern = os.path.join(tr_dir, f'transformed_examples/{tr_id}/Split-eval/transformed_examples-00000-of-00001.gz')

AUTOTUNE = tf.data.AUTOTUNE

def read_records(file_pattern, feature_spec, batch=50):
    return tf.data.TFRecordDataset(file_pattern, compression_type='GZIP') \
        .map(lambda x: tf.io.parse_example(x, feature_spec)) \
        .batch(batch) \
        .prefetch(buffer_size=tf.data.AUTOTUNE)

def split(x):
    xc = x.copy()
    target = xc.pop('target')
    return xc, target / 100.0

train_dataset = read_records(train_file_pattern, feature_spec).map(split).prefetch(buffer_size=AUTOTUNE)
val_dataset = read_records(val_file_pattern, feature_spec).map(split).prefetch(buffer_size=AUTOTUNE)

# %%
for x, y  in val_dataset:
    break
# y

# %% [markdown]
# ## Model dev cells

# %%
def batch_block_builder(input_size, block_size):
    
    inputs = Input(shape=(input_size,))
    x1 = Dense(block_size)(inputs)
    x1 = BatchNormalization()(x1)
    x1 = Activation('relu')(x1)
    
    return tf.keras.models.Model(inputs=inputs, outputs=x1) 


class CustomModel(tf.keras.models.Model):
    
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        
        self.big_dense = tf.keras.models.Sequential([
            batch_block_builder(10, 20),
            batch_block_builder(20, 20),
            batch_block_builder(20, 5),
            ])
        self.medium_dense = tf.keras.models.Sequential([
            batch_block_builder(40, 80),
            batch_block_builder(80, 80),
            batch_block_builder(80, 20),
            ])
        self.small_dense = tf.keras.models.Sequential([
            batch_block_builder(1, 5),
            batch_block_builder(5, 5),
            batch_block_builder(5, 1),
            ])
        self.z_norm_dense = tf.keras.models.Sequential([
            batch_block_builder(1, 5),
            batch_block_builder(5, 5),
            batch_block_builder(5, 1),
            ])
        self.cat_embedding = tf.keras.models.Sequential([
            Embedding(2, 5, name='cats'),
            Lambda(lambda x: x[:, 0, :]),
            batch_block_builder(5, 5),
            batch_block_builder(5, 5),
            batch_block_builder(5, 1),
        ])
            
        self.pred_submodel = tf.keras.models.Sequential([
            Dense(10, name='reducer'),
            BatchNormalization(),
            Activation('relu'),
            Dense(1, name='preds'),
            ])
    
    def call(self, x: Dict[Text, tf.Tensor], trainig=False) -> tf.Tensor:
           
        features = []
        features.append(self.z_norm_dense(x['z_normal']))
        features.append(self.small_dense(x['small_columns']))
        features.append(self.medium_dense(x['medium_columns']))
        features.append(self.big_dense(tf.cast(x['big_columns'], tf.float32)))
        features.append(self.cat_embedding(x['categorical']))
        
        features = tf.concat(features, axis=-1)
        preds = self.pred_submodel(features)
        
        return preds
    
model = CustomModel()
model(x)

model.summary()
# Out:
# Model: "custom_model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_15 (Sequential)  (None, 5)                 925
#
#  sequential_16 (Sequential)  (None, 20)                12100
#
#  sequential_17 (Sequential)  (None, 1)                 90
#
#  sequential_18 (Sequential)  (None, 1)                 90
#
#  sequential_19 (Sequential)  (None, 1)                 120
#
#  sequential_20 (Sequential)  (50, 1)                   341
#
# =================================================================
# Total params: 13666 (53.38 KB)
# Trainable params: 13130 (51.29 KB)
# Non-trainable params: 536 (2.09 KB)
# _________________________________________________________________
# 2024-07-18 09:49:20.536333: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.

# %%
tf.keras.backend.clear_session()

model_name = 'model_batch_norm_true_ref_x6'

## Build different model
model = CustomModel()
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
            initial_learning_rate=4e-3,
            decay_steps=10000,
            decay_rate=0.98)    
optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)

model.compile(loss='mean_squared_error',
                  optimizer=optimizer, 
                  metrics=[tf.keras.metrics.MeanAbsoluteError(),
                           tf.keras.metrics.MeanAbsolutePercentageError()])    
callbacks = build_callbacks(f'{model_name}', 
                            monitor='val_mean_absolute_percentage_error',
                            mode='min')

initial = 0
total = 20
model.fit(
  train_dataset,
  validation_data=val_dataset,
  initial_epoch=initial,
  epochs=total,
  verbose=1, 
  callbacks=callbacks)
# Out:
# Epoch 1/20
# 2024-07-18 09:49:36.246795: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xbcd2920 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-07-18 09:49:36.246849: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2024-07-18 09:49:36.255691: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-18 09:49:36.277300: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8907
# 2024-07-18 09:49:36.462910: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#    1440/Unknown - 55s 26ms/step - loss: 0.0620 - mean_absolute_error: 0.1855 - mean_absolute_percentage_error: 318.6889
# 2024-07-18 09:50:25.668304: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 4961231836824512645
# 2024-07-18 09:50:25.668375: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 11925116166579186899
# 2024-07-18 09:50:25.668397: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous recv item cancelled. Key hash: 8118860245551523550
# Epoch 1: val_mean_absolute_percentage_error improved from inf to 316.00253, saving model to ./checkpoints/model_batch_norm_true_ref_x6_epoch-01_val_mean_absolute_percentage_error-316.00253.h5
# 1440/1440 [==============================] - 58s 28ms/step - loss: 0.0620 - mean_absolute_error: 0.1855 - mean_absolute_percentage_error: 318.6889 - val_loss: 0.0678 - val_mean_absolute_error: 0.2295 - val_mean_absolute_percentage_error: 316.0025
# Epoch 2/20
# 1440/1440 [==============================] - ETA: 0s - loss: 0.0079 - mean_absolute_error: 0.0690 - mean_absolute_percentage_error: 90.9893
# Epoch 2: val_mean_absolute_percentage_error improved from 316.00253 to 61.79787, saving model to ./checkpoints/model_batch_norm_true_ref_x6_epoch-02_val_mean_absolute_percentage_error-61.79787.h5
# 1440/1440 [==============================] - 39s 27ms/step - loss: 0.0079 - mean_absolute_error: 0.0690 - mean_absolute_percentage_error: 90.9893 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285 - val_mean_absolute_percentage_error: 61.7979
# Epoch 3/20
# 1438/1440 [============================>.] - ETA: 0s - loss: 0.0055 - mean_absolute_error: 0.0580 - mean_absolute_percentage_error: 55.2203
# Epoch 3: val_mean_absolute_percentage_error improved from 61.79787 to 37.51743, saving model to ./checkpoints/model_batch_norm_true_ref_x6_epoch-03_val_mean_absolute_percentage_error-37.51743.h5
# 1440/1440 [==============================] - 39s 27ms/step - loss: 0.0055 - mean_absolute_error: 0.0580 - mean_absolute_percentage_error: 55.2951 - val_loss: 0.0016 - val_mean_absolute_error: 0.0323 - val_mean_absolute_percentage_error: 37.5174
# Epoch 4/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0050 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 42.6017
# Epoch 4: val_mean_absolute_percentage_error improved from 37.51743 to 21.22722, saving model to ./checkpoints/model_batch_norm_true_ref_x6_epoch-04_val_mean_absolute_percentage_error-21.22722.h5
# 1440/1440 [==============================] - 40s 28ms/step - loss: 0.0050 - mean_absolute_error: 0.0553 - mean_absolute_percentage_error: 42.6785 - val_loss: 7.0417e-04 - val_mean_absolute_error: 0.0204 - val_mean_absolute_percentage_error: 21.2272
# Epoch 5/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0048 - mean_absolute_error: 0.0541 - mean_absolute_percentage_error: 42.6617
# Epoch 5: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 39s 27ms/step - loss: 0.0048 - mean_absolute_error: 0.0541 - mean_absolute_percentage_error: 42.7816 - val_loss: 5.9699e-04 - val_mean_absolute_error: 0.0188 - val_mean_absolute_percentage_error: 31.7472
# Epoch 6/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0047 - mean_absolute_error: 0.0535 - mean_absolute_percentage_error: 45.8860
# Epoch 6: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 39s 27ms/step - loss: 0.0047 - mean_absolute_error: 0.0535 - mean_absolute_percentage_error: 46.0428 - val_loss: 9.5723e-04 - val_mean_absolute_error: 0.0238 - val_mean_absolute_percentage_error: 38.7784
# Epoch 7/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0046 - mean_absolute_error: 0.0529 - mean_absolute_percentage_error: 48.0383
# Epoch 7: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 40s 28ms/step - loss: 0.0046 - mean_absolute_error: 0.0529 - mean_absolute_percentage_error: 48.2351 - val_loss: 7.0862e-04 - val_mean_absolute_error: 0.0192 - val_mean_absolute_percentage_error: 33.1057
# Epoch 8/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0044 - mean_absolute_error: 0.0520 - mean_absolute_percentage_error: 47.8912
# Epoch 8: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 39s 27ms/step - loss: 0.0044 - mean_absolute_error: 0.0520 - mean_absolute_percentage_error: 47.9969 - val_loss: 5.7882e-04 - val_mean_absolute_error: 0.0178 - val_mean_absolute_percentage_error: 29.9150
# Epoch 9/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0044 - mean_absolute_error: 0.0517 - mean_absolute_percentage_error: 46.4291
# Epoch 9: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 39s 27ms/step - loss: 0.0044 - mean_absolute_error: 0.0517 - mean_absolute_percentage_error: 46.5685 - val_loss: 6.0501e-04 - val_mean_absolute_error: 0.0185 - val_mean_absolute_percentage_error: 24.9125
# Epoch 10/20
# 1438/1440 [============================>.] - ETA: 0s - loss: 0.0043 - mean_absolute_error: 0.0514 - mean_absolute_percentage_error: 47.4192
# Epoch 10: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 40s 28ms/step - loss: 0.0043 - mean_absolute_error: 0.0514 - mean_absolute_percentage_error: 47.5337 - val_loss: 4.9263e-04 - val_mean_absolute_error: 0.0164 - val_mean_absolute_percentage_error: 23.1045
# Epoch 11/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0043 - mean_absolute_error: 0.0513 - mean_absolute_percentage_error: 48.2892
# Epoch 11: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 39s 27ms/step - loss: 0.0043 - mean_absolute_error: 0.0513 - mean_absolute_percentage_error: 48.4162 - val_loss: 6.5580e-04 - val_mean_absolute_error: 0.0194 - val_mean_absolute_percentage_error: 25.7702
# Epoch 12/20
# 1440/1440 [==============================] - ETA: 0s - loss: 0.0043 - mean_absolute_error: 0.0511 - mean_absolute_percentage_error: 48.3519
# Epoch 12: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 39s 27ms/step - loss: 0.0043 - mean_absolute_error: 0.0511 - mean_absolute_percentage_error: 48.3519 - val_loss: 7.0521e-04 - val_mean_absolute_error: 0.0197 - val_mean_absolute_percentage_error: 26.5043
# Epoch 13/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0043 - mean_absolute_error: 0.0512 - mean_absolute_percentage_error: 47.9549
# Epoch 13: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 47s 32ms/step - loss: 0.0043 - mean_absolute_error: 0.0512 - mean_absolute_percentage_error: 48.0818 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265 - val_mean_absolute_percentage_error: 31.6361
# Epoch 14/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0042 - mean_absolute_error: 0.0509 - mean_absolute_percentage_error: 47.8730
# Epoch 14: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 45s 31ms/step - loss: 0.0042 - mean_absolute_error: 0.0509 - mean_absolute_percentage_error: 48.0088 - val_loss: 0.0012 - val_mean_absolute_error: 0.0287 - val_mean_absolute_percentage_error: 29.3742
# Epoch 15/20
# 1440/1440 [==============================] - ETA: 0s - loss: 0.0042 - mean_absolute_error: 0.0507 - mean_absolute_percentage_error: 48.8125
# Epoch 15: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 42s 29ms/step - loss: 0.0042 - mean_absolute_error: 0.0507 - mean_absolute_percentage_error: 48.8125 - val_loss: 0.0013 - val_mean_absolute_error: 0.0307 - val_mean_absolute_percentage_error: 33.4470
# Epoch 16/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0042 - mean_absolute_error: 0.0504 - mean_absolute_percentage_error: 48.9909
# Epoch 16: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 40s 27ms/step - loss: 0.0042 - mean_absolute_error: 0.0504 - mean_absolute_percentage_error: 49.1290 - val_loss: 0.0015 - val_mean_absolute_error: 0.0323 - val_mean_absolute_percentage_error: 34.5081
# Epoch 17/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0041 - mean_absolute_error: 0.0499 - mean_absolute_percentage_error: 49.1475
# Epoch 17: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 40s 28ms/step - loss: 0.0041 - mean_absolute_error: 0.0499 - mean_absolute_percentage_error: 49.2835 - val_loss: 0.0030 - val_mean_absolute_error: 0.0470 - val_mean_absolute_percentage_error: 39.5230
# Epoch 18/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0040 - mean_absolute_error: 0.0494 - mean_absolute_percentage_error: 49.6866
# Epoch 18: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 39s 27ms/step - loss: 0.0040 - mean_absolute_error: 0.0494 - mean_absolute_percentage_error: 49.8102 - val_loss: 0.0027 - val_mean_absolute_error: 0.0441 - val_mean_absolute_percentage_error: 35.4752
# Epoch 19/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0039 - mean_absolute_error: 0.0489 - mean_absolute_percentage_error: 49.9007
# Epoch 19: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 44s 30ms/step - loss: 0.0039 - mean_absolute_error: 0.0489 - mean_absolute_percentage_error: 50.0005 - val_loss: 0.0030 - val_mean_absolute_error: 0.0463 - val_mean_absolute_percentage_error: 34.7467
# Epoch 20/20
# 1439/1440 [============================>.] - ETA: 0s - loss: 0.0038 - mean_absolute_error: 0.0482 - mean_absolute_percentage_error: 49.7837
# Epoch 20: val_mean_absolute_percentage_error did not improve from 21.22722
# 1440/1440 [==============================] - 43s 30ms/step - loss: 0.0038 - mean_absolute_error: 0.0482 - mean_absolute_percentage_error: 49.8558 - val_loss: 0.0038 - val_mean_absolute_error: 0.0537 - val_mean_absolute_percentage_error: 33.5426

# %%
model.load_weights('./checkpoints/model_batch_norm_true_x5_epoch-13_val_mean_absolute_percentage_error-16.05021.h5')

# %% [markdown]
# ## Check outputs by hands

# %%
for x1, y in val_dataset.take(1):
    pass
tf.reduce_mean(tf.abs(model(x1) - y) * 100)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=1.5244832>

# %%
pd.DataFrame({'preds':model(x1).numpy()[:, 0] * 100 , "trues":y.numpy()[:, 0] * 100})
# Out:
#         preds      trues
# 0   21.205040  20.439486
# 1   50.885403  50.238983
# 2   57.757652  55.973370
# 3   95.274605  98.506592
# 4   61.422546  60.348804
# 5   57.260883  55.468987
# 6   39.243706  40.220413
# 7   16.639652  14.367920
# 8   48.936169  47.718895
# 9   95.373772  98.101608
# 10  65.630829  64.287376
# 11  54.701550  53.668636
# 12  62.115143  60.707603
# 13  55.421684  53.732265
# 14  47.985287  47.580215
# 15   9.161882   6.702786
# 16  87.906906  88.812599
# 17  58.000313  56.326900
# 18   9.486670   7.254177
# 19  20.873758  24.568108
# 20  84.515427  84.824463
# 21  69.881149  69.236984
# 22  25.705612  26.406775
# 23  63.580917  62.165333
# 24  81.971451  82.097481
# 25   9.018811   6.366065
# 26  91.222023  91.028763
# 27  94.775902  95.592415
# 28  92.587807  95.888756
# 29  93.869232  93.916679
# 30  18.017780  19.259605
# 31  90.042809  86.005264
# 32  43.133617  42.011871
# 33  50.863796  49.289085
# 34  59.688232  57.967522
# 35  44.376865  44.700706
# 36  31.603807  32.714249
# 37  75.413422  74.479179
# 38  55.838310  54.263802
# 39  31.865898  34.633427
# 40  33.995239  34.412758
# 41  82.527222  82.529053
# 42  54.777264  53.714855
# 43  64.867188  63.572353
# 44  37.167934  38.685093
# 45  37.517868  38.955238
# 46  66.503357  65.159256
# 47  21.874739  25.736412
# 48  69.034981  67.775711
# 49  89.983536  85.900414

# %% [markdown]
# ## Save model

# %%
tf.saved_model.save(model, './custom_model')
